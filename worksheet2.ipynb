# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4a240306-blip/Saurav-Sapkota/blob/main/worksheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Creating a simple Series
data = [10, 20, 30, 40]
series = pd.Series(data)
print(series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Default Index
import pandas as pd

series = pd.Series([10, 20, 30])
print(series.index)


# User Defined Index
series = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(series)


# Datetime Index
dates = pd.date_range('2023-01-01', periods=3)
series = pd.Series([10, 20, 30], index=dates)
print(series)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# a    10
# b    20
# c    30
# dtype: int64
# 2023-01-01    10
# 2023-01-02    20
# 2023-01-03    30
# Freq: D, dtype: int64

# %%
import pandas as pd

# Access Index
series = pd.Series([10, 20, 30], index=['a', 'b', 'c'])
print(series.index)     # Shows the index


# Set or Reset Index for Series
series.index = ['x', 'y', 'z']   # Changing the index of a Series
print(series)


# For DataFrame
df = pd.DataFrame({'A': [1, 2]}, index=['row1', 'row2'])
df.reset_index(inplace=True)
print(df)
# Converts the index into a column
# Out:
# Index(['a', 'b', 'c'], dtype='object')
# x    10
# y    20
# z    30
# dtype: int64
#   index  A
# 0  row1  1
# 1  row2  2

# %%
import pandas as pd

df1 = pd.DataFrame({
    'Bob': ['I liked it.', 'It was awful'],
    'Sue': ['Pretty good.', 'Bland.']
})

print(df1)
# Out:
#             Bob           Sue
# 0   I liked it.  Pretty good.
# 1  It was awful        Bland.

# %%
import pandas as pd

pd.DataFrame({
    'Bob': ['I liked it.', 'It was awful'],
    'Sue': ['Pretty good.', 'Bland.']
})
# Out:
#             Bob           Sue
# 0   I liked it.  Pretty good.
# 1  It was awful        Bland.

# %%
import pandas as pd

pd.DataFrame({
    'Bob': ['I liked it.', 'It was awful.'],
    'Sue': ['Pretty good.', 'Bland.']
},
index=['Product A', 'Product B']
)
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
# Importing Data from file
import pandas as pd

# Creating a dictionary
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'City': ['New York', 'San Francisco', 'Los Angeles']
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Writing DataFrame to CSV
df.to_csv('output.csv', index=False)

# Run the above code and observe the output.

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
}

df = pd.DataFrame(data)

# View the first two rows
print(df.head(2))

# View the last row
print(df.tail(1))

# DataFrame information
print(df.info())

# Summary statistics
print(df.describe())

# Check dimensions of the DataFrame
print(f"The DataFrame has {df.shape[0]} rows and {df.shape[1]} columns.")

# Access the 'Age' column
print(df['Age'])

# Select rows by numerical index
print(df.iloc[0])  # First row

# Select rows by condition
print(df.loc[df['Age'] > 30])  # Rows where Age > 30
# Out:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000
#       Name  Age  Salary
# 2  Charlie   35   70000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes
# None
#         Age   Salary
# count   3.0      3.0
# mean   30.0  60000.0
# std     5.0  10000.0
# min    25.0  50000.0
# 25%    27.5  55000.0
# 50%    30.0  60000.0
# 75%    32.5  65000.0
# max    35.0  70000.0
# The DataFrame has 3 rows and 3 columns.
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
# Name      Alice
# Age          25
# Salary    50000
# Name: 0, dtype: object
#       Name  Age  Salary
# 2  Charlie   35   70000

# %%
import pandas as pd

# Sample DataFrame with a missing value in 'Age'
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, None],
    'Salary': [50000, 60000, 55000]
}

df = pd.DataFrame(data)

# Check info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     2 non-null      float64
#  2   Salary  3 non-null      int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 204.0+ bytes

# %%
import pandas as pd

# Sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, None],
    'Salary': [50000, 60000, 55000]
}

df = pd.DataFrame(data)

# Check summary statistics
print(df.describe())
# Out:
#              Age   Salary
# count   2.000000      3.0
# mean   27.500000  55000.0
# std     3.535534   5000.0
# min    25.000000  50000.0
# 25%    26.250000  52500.0
# 50%    27.500000  55000.0
# 75%    28.750000  57500.0
# max    30.000000  60000.0
